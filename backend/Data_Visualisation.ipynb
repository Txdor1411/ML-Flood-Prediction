# %%
import numpy as np
import rasterio
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#RECAPITULARE ROAI # AM INNEBUNIT
# import numpy, pandas
# test_df = pd.read...
# train_df = pd.read...

# visualize the data
#plt.scatter(...)

#Imputing missing values
# train_test_split = random state, test_size = 0.2

#import model

#model.fit(X_train, y_train)
#model.predict(X_test)
#evaluate the model

#encoding : label, one hot (pd.get_dummies)

#task = pd.DataFrame(
# ...)

#task.to_csv('submission.csv', index=False)

# %%
with rasterio.open('cluj_dem.tif') as src:
    raster_data = src.read(1)  # Read the first band

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(raster_data, cmap=plt.cm.viridis, linewidth=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 fig = plt.figure()
# ----> 2 ax = fig.gca(projection='3d')
#       3 ax.plot_trisurf(raster_data, cmap=plt.cm.viridis, linewidth=0.2)
#       4 plt.show()
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'
